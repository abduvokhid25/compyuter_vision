# %% [markdown]
# <a href="https://colab.research.google.com/github/abduvokhid25/compyuter_vision/blob/main/data_scrabing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %%
downloader.download(
    "uzbek pilaf plov food",
    limit=100,
    output_dir="/content/pilaf_images",
    adult_filter_off=True,
    force_replace=True,
    timeout=60
)
# Out:
# [%] Downloading Images to /content/pilaf_images/uzbek pilaf plov food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 50 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://m.media-amazon.com/images/I/71C4tqbgm9L.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://www.hdforums.com/forum/attachments/dyna-glide-models/365305d1395217827-12-fat-mini-ape-handlebar-kit-with-riser-satin-black-170325-f3fidy-albums-28722-2010-wide-glide-picture192873-vivid-black-02.jpg
# [!] Issue getting: https://www.hdforums.com/forum/attachments/dyna-glide-models/365305d1395217827-12-fat-mini-ape-handlebar-kit-with-riser-satin-black-170325-f3fidy-albums-28722-2010-wide-glide-picture192873-vivid-black-02.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #2 from https://m.media-amazon.com/images/I/71kGisgh3VL._AC_UF894,1000_QL80_.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://i.pinimg.com/474x/b9/17/03/b91703865398bdd14b76a922a0ee927f.jpg
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil
from google.colab import drive


drive.mount('/content/drive')

source_dir = '/content/pilaf_images/uzbek pilaf plov food'
target_dir = '/content/drive/MyDrive/Food_101_Dataset/pilaf'

os.makedirs(target_dir, exist_ok=True)
for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
downloader.download(
    "kebab shashlik food",
    limit=100,
    output_dir='/content/kebab_images',
    adult_filter_off=True,
    force_replace=False,
    timeout=60
)
# Out:
# [%] Downloading Images to /content/kebab_images/kebab shashlik food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 60 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.tipperarylive.ie/jpim-static/image/2026/04/18/12/iconic-upload-2025_01_14-MixCollage-14-Jan-2025-04-10-PM-6477-1736871524291.jpg?width=1000&auto=webp&quality=75&crop=3:2,smart&trim=
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://www.theblondeabroad.com/wp-content/uploads/2023/02/Pin1_Best-Summer-Destinations-in-Europe-768x1213.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://www.outtraveler.com/media-library/top-15-world-vacation-destinations.jpg?id=33673330&width=980
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://i.ytimg.com/vi/6eE4pSUDa9k/maxresdefault.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://www.sparrowexplorer.com/wp-content/uploads/2023/04/Best-Travel-Destinations-Worldwide-2023-2024_-1024x577.webp
# ...

# %%
import os, shutil


drive.mount('/content/drive')

source_dir = '/content/kebab_images/kebab shashlik food'
target_dir = '/content/drive/MyDrive/Food_101_Dataset/kebab'

os.makedirs(target_dir, exist_ok=True)
for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
